# %%
#Install dataset
# !pip install astroquery
# Out:
# Requirement already satisfied: astroquery in c:\users\tdavi\anaconda3\lib\site-packages (0.4.7)
# Requirement already satisfied: numpy>=1.18 in c:\users\tdavi\anaconda3\lib\site-packages (from astroquery) (1.26.4)
# Requirement already satisfied: astropy>=4.2.1 in c:\users\tdavi\anaconda3\lib\site-packages (from astroquery) (6.1.0)
# Requirement already satisfied: requests>=2.19 in c:\users\tdavi\anaconda3\lib\site-packages (from astroquery) (2.32.2)
# Requirement already satisfied: beautifulsoup4>=4.8 in c:\users\tdavi\anaconda3\lib\site-packages (from astroquery) (4.12.3)
# Requirement already satisfied: html5lib>=0.999 in c:\users\tdavi\anaconda3\lib\site-packages (from astroquery) (1.1)
# Requirement already satisfied: keyring>=15.0 in c:\users\tdavi\anaconda3\lib\site-packages (from astroquery) (24.3.1)
# Requirement already satisfied: pyvo>=1.1 in c:\users\tdavi\anaconda3\lib\site-packages (from astroquery) (1.6)
# Requirement already satisfied: pyerfa>=2.0.1.1 in c:\users\tdavi\anaconda3\lib\site-packages (from astropy>=4.2.1->astroquery) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.4.29.0.28.48 in c:\users\tdavi\anaconda3\lib\site-packages (from astropy>=4.2.1->astroquery) (0.2024.6.3.0.31.14)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\tdavi\anaconda3\lib\site-packages (from astropy>=4.2.1->astroquery) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in c:\users\tdavi\anaconda3\lib\site-packages (from astropy>=4.2.1->astroquery) (23.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\tdavi\anaconda3\lib\site-packages (from beautifulsoup4>=4.8->astroquery) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\tdavi\anaconda3\lib\site-packages (from html5lib>=0.999->astroquery) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\tdavi\anaconda3\lib\site-packages (from html5lib>=0.999->astroquery) (0.5.1)
# Requirement already satisfied: jaraco.classes in c:\users\tdavi\anaconda3\lib\site-packages (from keyring>=15.0->astroquery) (3.2.1)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\tdavi\anaconda3\lib\site-packages (from keyring>=15.0->astroquery) (0.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tdavi\anaconda3\lib\site-packages (from requests>=2.19->astroquery) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tdavi\anaconda3\lib\site-packages (from requests>=2.19->astroquery) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tdavi\anaconda3\lib\site-packages (from requests>=2.19->astroquery) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tdavi\anaconda3\lib\site-packages (from requests>=2.19->astroquery) (2024.8.30)
# Requirement already satisfied: more-itertools in c:\users\tdavi\anaconda3\lib\site-packages (from jaraco.classes->keyring>=15.0->astroquery) (10.1.0)

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import pandas as pd
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
#Implementation cell
from sklearn.neighbors import NearestNeighbors


def calculateEpsilon(data, P, initialEpsilon, threshold):
    """
    Calculate dynamic epsilon for point P based on the density of the neighborhood.
    """
    neighbors = findNeighbors(data, P, initialEpsilon)
    density = len(neighbors)

    if density > threshold:
        epsilon = initialEpsilon * (threshold / density)
    else:
        epsilon = initialEpsilon
    return epsilon

def findNeighbors(data, P, epsilon):
    """
    Find all neighbors of point P within distance epsilon.
    """
    data_array = data.values if isinstance(data, pd.DataFrame) else data

    nbrs = NearestNeighbors(radius=epsilon).fit(data_array)
    indices = nbrs.radius_neighbors([data_array[P]], return_distance=False)[0]
    return list(indices)

def expandCluster(data, labels, P, neighbors, clusterID, epsilon, minSamples):
    """
    Expands a cluster starting from point P, checking its neighbors and iterating to expand the cluster.
    """
    labels[P] = clusterID
    pointsToCheck = neighbors.copy()

    while pointsToCheck:
        point = pointsToCheck.pop()

        if labels[point] == 0:
            epsilon = calculateEpsilon(data, point, epsilon, threshold=40)

            newNeighbors = findNeighbors(data, point, epsilon)

            if len(newNeighbors) >= minSamples:
                pointsToCheck.extend(newNeighbors)

        if labels[point] <= 0:
            labels[point] = clusterID

#Main DBSCAN function
def improvedDBSCAN(data, initialEpsilon, minSamples, threshold):
    labels = np.zeros(len(data))
    clusterID = 0

    for P in range(len(data)):
        if labels[P] != 0: 
            continue

        epsilon = calculateEpsilon(data, P, initialEpsilon, threshold)

        neighbors = findNeighbors(data, P, epsilon)

        if len(neighbors) < minSamples:
            labels[P] = -1
        else:
            clusterID += 1
            expandCluster(data, labels, P, neighbors, clusterID, epsilon, minSamples)

    return labels

# %%
#Data preparation for dataset #1 (Planets dataset)
from astroquery.ipac.nexsci.nasa_exoplanet_archive import NasaExoplanetArchive

exoplanets = NasaExoplanetArchive.query_criteria(table="ps", select="pl_name, pl_orbper, pl_radj")
exoplanets_df = exoplanets.to_pandas()
data = exoplanets_df
data = data.dropna()

#Removing largest values from datasets, which skewed results
data = data[data['pl_orbper'] < data['pl_orbper'].nlargest(450).min()]
data = data[data['pl_radj'] < data['pl_radj'].nlargest(450).min()]

#Limit to 1000
data = data.iloc[:1000]
#Removing values again after data reduction
data = data[data['pl_orbper'] < data['pl_orbper'].nlargest(11).min()]
data = data[['pl_orbper', 'pl_radj']]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 989 entries, 0 to 1720
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pl_orbper  989 non-null    float64
#  1   pl_radj    989 non-null    float64
# dtypes: float64(2)
# memory usage: 23.2 KB

# %%
from sklearn.preprocessing import StandardScaler

#Scaling features for DBSCAN
scaler = StandardScaler()
X = data[['pl_orbper', 'pl_radj']]
X_scaled = scaler.fit_transform(X) #commented out scaler 

X_scaled = pd.DataFrame(X_scaled, columns=['pl_orbper', 'pl_radj'])
X = X_scaled

# %%
#Running improved DBSCAN with data
labels = improvedDBSCAN(X, initialEpsilon=0.70, minSamples=12, threshold=24)

X_= pd.DataFrame(X, columns=['pl_orbper', 'pl_radj'])
X['Cluster'] = labels
X.head()
# Out:
#    pl_orbper   pl_radj  Cluster
# 0  -0.528841  1.756817      1.0
# 1  -0.669765 -0.794334      2.0
# 2  -0.447877 -0.882227     -1.0
# 3  -0.230095 -0.749261      6.0
# 4   0.246765 -0.575729      6.0

# %%
#Plot cell
unique_labels = X['Cluster'].unique()
num_clusters = len(unique_labels) - (1 if -1 in unique_labels else 0)  #Exclude noise if present
colors = {
    1: 'green', 2: 'blue', 3: 'lime', 4: 'purple', 5: 'orange', 6: 'magenta', 7: 'pink', 8: 'brown', 
    9: 'turquoise', 10: 'gold', 11: 'red', 12: 'cyan', 13: 'crimson', 14: 'violet', 15: 'indigo', 16: 'yellow'
}
handles = []
labels = []

#Plot each point with a color based on its cluster label
plt.figure(figsize=(10, 6))
for label in unique_labels:
    if label == -1:
        #Plot noise points in white
        scatter = plt.scatter(X[X['Cluster'] == label]['pl_orbper'], 
                    X[X['Cluster'] == label]['pl_radj'], 
                    c='white', label='Noise', s=50, marker='o', edgecolor='k', alpha=0.6)
    else:
        #Plot clusters with different colors
        color = colors.get(label, 'gray')
        scatter = plt.scatter(X[X['Cluster'] == label]['pl_orbper'], 
                    X[X['Cluster'] == label]['pl_radj'], 
                    color=color, label=f'Cluster {int(label)}', s=50, marker='o', edgecolor='k', alpha=0.6)

    handles.append(scatter)
    labels.append(label)

sorted_labels_and_handles = sorted(zip(labels, handles), key=lambda x: (x[0] != -1, x[0]))
sorted_labels, sorted_handles = zip(*sorted_labels_and_handles)
formatted_labels = ['Noise' if label == -1 else f'Cluster {int(label)}' for label in sorted_labels]

#Labeling the plot
plt.title("Improved DBSCAN Clustering of Planet Data")
plt.xlabel("Orbital Period")
plt.ylabel("Planet Radius")
plt.legend(handles=sorted_handles, labels=formatted_labels)
plt.show()
